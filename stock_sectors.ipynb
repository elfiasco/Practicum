# %%
import pandas as pd
import numpy as np
import time
from yahooquery import Ticker
import yfinance as yf

# %%
data = pd.read_csv('data.csv')
for i in set(data['sector']):
    print(i)
    print(np.unique(data.loc[data['sector'] == i, 'industry']))
    print()
# Out:
# nan
# []
#
# Miscellaneous
# ['Business Services' 'Diversified Commercial Services'
#  'Industrial Machinery/Components' 'Office Equipment/Supplies/Services'
#  'Other Consumer Services']
#
# Finance
# ['Accident &Health Insurance' 'Advertising' 'Business Services'
#  'Commercial Banks' 'Diversified Financial Services' 'Finance Companies'
#  'Finance/Investors Services' 'Finance: Consumer Services'
#  'Investment Bankers/Brokers/Service' 'Investment Managers'
#  'Life Insurance' 'Major Banks' 'Property-Casualty Insurers' 'Real Estate'
#  'Savings Institutions' 'Specialty Insurers'
#  'Trusts, Except Educational, Religious, and Charitable']
#
# Transportation
# ['Air Freight/Delivery Services' 'Oil Refining/Marketing' 'Railroads'
#  'Trucking Freight/Courier Services']
#
# Consumer Staples
# ['Beverages (Production/Distribution)' 'Consumer Electronics/Appliances'
#  'Farming/Seeds/Milling' 'Food Chains' 'Meat/Poultry/Fish'
# ...

# %%
symbols = ['RNWK', 'GOLD', 'NU', 'DIS', 'PG', 'KMB', 'PYPL', 'CLX', 'QCOM', 'C', 'FWONK', 'LSXMK', 'LBRDK', 'SYK', 'META', 'MDT', 'MLM', 'FFIV', 'ELAN', 'CMCSA', 'BAX', 'GOOG', 'ADBE', 'RPM', 'NVDA', 'MSFT', 'AAPL', 'AMZN', 'ZTS', 'TJX', 'TMO', 'LRCX', 'TSM', 'INTC', 'F', 'ATVI', 'CLF', 'X', 'WIW', 'GBIL', 'LUBYX', 'LDP', 'BATRK', 'LBRDA', 'BATRA', 'XOM', 'CVX', 'VCTR', 'VRTX', 'TREX', 'SCI', 'RELX', 'RH', 'PHM', 'PAYC', 'GIS', 'GLPI', 'RACE', 'EXR', 'ETSY', 'ELS', 'DQ', 'CROX', 'CSCO', 'AMGN', 'AMT', 'WIT', 'SEIC', 'RMD', 'TROW', 'NOC', 'MNST', 'MASI', 'MKTX', 'IDXX', 'HON', 'GGG', 'IT', 'GRMN', 'FAST', 'EL', 'DHI', 'CHD', 'AMAT', 'ALGN', 'APD', 'MRO', 'OXY', 'FTBFX', 'FDX', 'BMN', 'MBXIX', 'GSMYX', 'SBPYX', 'FCPIX', 'VZ', 'CVS', 'DLR', 'MPW', 'SRVR', 'EFAD', 'GMRE', 'JHEM', 'ABT', 'HDGE', 'PSQ', 'SH', 'HQL', 'NID', 'SBIO', 'FIVE', 'ARKK', 'ECOM', 'SQM', 'WFC', 'IVV', 'EFAV', 'XLY', 'VTRS', 'ABNFX', 'RSP', 'IDV', 'DHS', 'PCNNX', 'JHCBX', 'ORCL', 'XLC', 'TSCO', 'MUB', 'OC', 'SSYS', 'GSIMX', 'IJS', 'JHMM', 'LGI', 'KRE', 'CDL', 'CFA', 'PRF', 'EELV', 'SPGP', 'CEF', 'GLD', 'GNR', 'CIBR', 'QTEC', 'GDXJ', 'MOO', 'GSSC', 'SMDV', 'DGRS', 'FINX', 'FDRR', 'FQAL', 'FIASX', 'BKEPP', 'HR', 'GWW', 'COST', 'LMT', 'KO', 'CAT', 'SBNY', 'MMM', 'CMS', 'IBM', 'BMY', 'VTIP', 'IBDO', 'IBDQ', 'BRK.B', 'SCCO', 'EVT', 'ABYIX', 'JCI', 'FDN', 'RTH', 'NXTG', 'LMND', 'FSK', 'TCF', 'SQ', 'IRT', 'RTX', 'TACO', 'WST', 'VEEV', 'VMW', 'SNA', 'SIVB', 'SPGI', 'ROK', 'REGN', 'NFLX', 'LMST', 'KEY', 'INTU', 'GNRC', 'FGBI', 'FITB', 'EXP', 'DEO', 'CFG', 'CE', 'CP', 'CABO', 'BKE', 'BIO', 'BMO', 'RF', 'NDAQ', 'MRK', 'MMC', 'MKSI', 'HUMA', 'GFI', 'CDNS', 'AME', 'ABBV', 'KWEB', 'MAXR', 'NEE', 'LHX', 'LOW', 'ROAD', 'UL', 'WEX', 'VFC', 'OTIS', 'HSIC', 'CARR', 'HSY', 'LIN', 'BABA', 'WBA', 'PFE', 'DOW', 'DUK', 'ABC', 'CTAS', 'PEP', 'PM', 'PONCX', 'TSN', 'XEL', 'ABQCX', 'FUN', 'CRWD', 'FGSCX', 'GILD', 'CLOU', 'NWL', 'PEGA', 'ACN', 'AWK', 'LLY', 'MA', 'WMT', 'LUBFX', 'GEMIX', 'XAR', 'PTMC', 'FIMKX', 'ITA', 'SI', 'IVOO', 'KBA', 'IWN', 'TTE', 'ARCC', 'FXI', 'MET', 'AXS', 'GLAD', 'HASI', 'ETN', 'IRM', 'APO', 'GLW', 'V', 'VFH', 'RIO', 'KBE', 'MOS', 'AQN', 'IGHG', 'PTNQ', 'AY', 'JNJ', 'NVS', 'USB', 'BAC', 'PII', 'CI', 'BK', 'KR', 'FB', 'DVA', 'QQQ', 'DDOG', 'RHP', 'RNR', 'PNFP', 'ENVA', 'CCEP', 'BKEP', 'NS', 'CLDT', 'CEM', 'VRM', 'CTAA', 'GOOGL', 'TTD', 'DELL', 'CAG', 'OFC', 'SPG', 'APAM', 'AON', 'CALX', 'AA', 'GE', 'UAA', 'UA', 'BDX', 'D', 'GD', 'SNOW', 'MPWR', 'KEYS', 'KLAC', 'ALLE', 'WAL', 'DECK', 'CHE', 'BHP', 'ATHM', 'BTC', 'J', 'NRDY', 'MCHP', 'T', 'SSBK', 'LMRK', 'WW', 'ARE', 'COR', 'MTUM', 'DTD', 'RDSA', 'PINS', 'SNAP', 'O', 'SDOG', 'TDY', 'WY', 'ONEQ', 'DG', 'BRK-B', 'CSX', 'WAT', 'TER', 'SWKS', 'DGX', 'ODFL', 'NDSN', 'NTES', 'IEX', 'GNTX', 'FTNT', 'EA', 'EBAY', 'EW', 'CNR', 'CL', 'ADP', 'FCX', 'FDSWX', 'JPM', 'OGN', 'NOK', 'BA', 'ETHE', 'GBTC', 'FL4.SG', 'CMG', 'QRTEA', 'PTON', 'IWM', 'NTRA', 'NUAN', 'GAN', 'TRIT', 'CWEN', 'MTCH', 'VPU', 'ITW', 'UBSI', 'BLK', 'STZ', 'AVGO', 'QRTEP', 'CARG', 'DGNR', 'STX', 'PENN', 'DD', 'GGSM', 'FEMS', 'EEM', 'LMACU', 'GME', 'SHOP', 'TSLA', 'STAG', 'AEP', 'XCAPX', 'PBA', 'VIAV', 'EVOP', 'RODM', 'FEYE', 'AJRD', 'CRSP', 'UNH', 'PSX', 'SYY', 'DNKN', 'NTAP', 'PLUG', 'EXPI', 'ETY', 'W', 'ZM', 'AIV', 'NTRP', 'UPS', 'SBUX', 'PLD', 'BYND', 'DAL', 'SNPS', 'OHI', 'ERIC', 'MRVL', 'BRKR', 'MANT', 'ACIW', 'CONE', 'GMAB', 'BAH', 'HBI', 'NTLA', 'PTLC', 'ARNA', 'PAGS', 'CTVA', 'HAL', 'PAAS', 'FTV', 'WDAY', 'BBY', 'NVAX', 'IJR', 'CB', 'TT', 'ATOAX', 'AMWD', 'IRBT', 'SLB', 'COP', 'TXN', 'ALL', 'RDS-B', 'MPC', 'TCEHY', 'PSA', 'COUP', 'MAR', 'VAC', 'OSK', 'ICE', 'NKLA', 'TGT', 'AAL', 'SPOT', 'SIL', 'DLS', 'TRIP', 'BAM', 'VMC', 'BERY', 'PRJAX', 'UBER', 'QSR', 'MCD', 'DPZ', 'BLL', 'BRY', 'RTN', 'LYV', 'MU', 'LGF-B', 'GPK', 'DVN', 'ALB', 'URBN', 'AXTA', 'VIAC', 'WPX', 'GM', 'SPY', 'VEA', 'VOO', 'CAIFX', 'FRIAX', 'AMLP', 'ENB', 'TRP', 'CEQP', 'EQM', 'NWSA', 'NKE', 'BX', 'ANTM', 'FOX', 'CTSH', 'ACA', 'MDLZ', 'BOIVF', 'RL', 'STT', 'UHAL', 'MO', 'KMI', 'HCA', 'PRU', 'EMR', 'M', 'SU', 'FHB', 'BKNG', 'FOXA', 'HUN', 'NWS', 'UN', 'MSM', 'EAF', 'PAGP', 'PSXP', 'SUN', 'TCP', 'EPD', 'LNG', 'MMP', 'OKE', 'PAA', 'SHLX', 'WMB', 'TRGP', 'MPLX', 'ET', 'HD', 'BP', 'AFL', 'TFC', 'SOJA', 'URI', 'SO', 'NSC', 'BIF', 'GDV', 'TEL', 'GRUB', 'PNQI', 'GEM', 'IAT', 'QLEIX', 'OAYIX', 'FPL', 'BOTZ', 'DRI', 'IWD', 'PKG', 'KNX', 'HPQ', 'NVO', 'TEX', 'KHC', 'HIG', 'DFS', 'UTX', 'K', 'GS', 'AIG', 'AGN', 'AGCO', 'CTXS', 'SAP', 'DOCU', 'JD', 'CME', 'FIS', 'WDC', 'TRV', 'PGR', 'PANW', 'NNVC', 'GLNCY', 'CR', 'CAH', 'AIZ', 'ADM', 'HELE', 'IPHI', 'VTR', 'TDG', 'DXCM', 'PODD', 'ILMN', 'CGNX', 'SIEGY', 'WCMIX', 'CZR', 'GEL', 'CDLX', 'VOD', 'ROST', 'LULU', 'AZO', 'WM', 'VWO', 'IR', 'FNKO', 'EEFT', 'ORLY', 'ROKU', 'KL', 'BSTZ', 'DCP', 'WES', 'BMEZ', 'DHR', 'REZI', 'ENTG', 'KSS', 'BFAM', 'IP', 'BIV', 'VFIJX', 'TGBAX', 'GTX', 'PPL', 'AM', 'CBS', 'IVZ', 'TWO', 'EXC', 'KTB', 'CELG', '3V64.TI', 'JNK', '0QZI.IL', 'XBI', 'BPL', 'CVET', 'AKAM', 'ETP', 'BBT', 'FRT', 'MALOX', 'GTCSX', 'TSCIX', 'VPMAX', 'IWF', 'REVB', 'ABB', 'SMG', 'ANDX', 'MYL', 'BWXT', 'NSRGY', 'RDSA.AS', 'HBAN', 'RHT', 'VGR', 'INFY', 'AVP', 'TOT', 'SHW', 'ISRG', 'LM09.SG', 'BRKB', 'APC', 'WTW', 'FDC', 'LH', 'CLR', 'KDP', 'SFTBY', 'SRE', 'RBGLY', 'PDRDY', 'LRLCY', 'MRAAY', 'NPSNY', 'MCO', 'LVS', 'KYCCF', 'SAFRY', 'HLT', 'GDDY', 'ESLOY', 'DE', 'CCI', 'CABGY', 'ASML', 'AZN', 'AHKSY', 'EADSY', 'AAGIY', 'BIIB', 'XSLV', 'PRNHX', 'FLMVX', 'FCNTX', 'ANCX', 'HAS', 'XLNX', 'IQV', 'HOLX', 'ADI', 'ZAYO', 'CHTR', 'LYB', 'WGP', 'MKC', 'AXP', 'EDIT', 'PPG', 'DWDP', 'AX', 'TNTOF', 'KN', 'KMX', 'TAP', 'BUD', 'UNP', 'COF', 'APTV', 'XPO', 'VLP', 'CFR', 'GFAFX', 'AET', 'INCY', 'SHECY', 'DISCA', 'MSTY.PA', 'PX', 'CRM', 'ON', 'WAB', 'LEA', 'TBT', 'CUTR', 'CAPL', 'WPZ', 'IIN', 'UNFI', 'RSPP', 'BTO', 'ST', 'TWX', 'CRMT', 'USG', 'TCMD', 'RCL', 'BNPQY', 'BOX', 'MGA', 'FE', 'PTEN', 'WEC', 'PAYX', 'IBM.MX', 'HRS', 'FDS', 'ES', 'EV', 'VGK', 'MS', 'IYE', 'RHHBY', 'CLB', 'CHK', 'AL', 'COHR', 'CHKP', 'WPC', 'CGNT', 'FANUY', 'XSD', 'RYT', 'IYT', 'CERN', 'IHE', 'RDS-A', 'RYAAY', 'HXL', 'AYI', 'PFS', 'JETS', 'LSCC', 'ENTL', 'HACK', 'SGAPY', 'SSDOY', 'DISH', 'BBL', 'CHRW', 'RGC', 'LVLT', '^MWE', '^RGP', 'PHLD', 'PCLN', 'XON', 'SOUHY', 'TMUS', 'MAT', 'HALO', 'DD-PA', 'VSM', 'WF', 'TCS', 'BIDU', 'ZIOP', 'SJM', 'CC', 'TD', 'LVMUY', 'CMPGY', 'BASFY', 'AXAHY', 'MCK', 'VTKLY', 'SMECF', 'NPSND', 'JKHY', 'PKI', 'NGG', 'BHF', 'Q', 'DVMT', 'SCG', 'HRL', 'NPK', 'RHI', 'PEY', 'WLK', 'WFM', 'AEX.MU', 'LW', 'DPS', 'FLR', 'ZNGA.SW', 'MCC', 'NFX', 'WRK', 'TUP', 'TEVA', 'STI', 'SNY', 'SABR', 'RAI', 'PDM', 'MXIM', 'MDC', 'MTB', 'KAR', 'GSK', 'ETR', 'CMA', 'BGS', 'APA', 'DLPH', 'POT', 'BIVV', 'LB', 'TWTR', 'VEVIX', 'BCR', 'NXPI', 'LLTC', 'WETF', 'AGU', 'TLLP', 'WOOF', 'SYF', 'FL', 'ESRX', 'YUMC', 'YUM', 'VIAB', 'AQFH', 'NEE-PC', 'ARW', 'PRGO', 'SRCL', 'TMK', 'MTD', 'ZBH', 'OKS', 'ZNGA', 'VSAT', 'VLO', 'CTL', 'JWN', 'AMG', 'IAI', 'MDU', 'SE', 'CAB', 'DPM', 'ASIX', 'HDS', 'HSBC', 'A', 'BUNT', 'HYH', 'EMC', 'BBU', 'AXLL', 'AFTEX', 'XLI', 'UA-C', 'SHPG', 'BIN', 'WCN', 'AEE', 'WTR', 'CPGX', 'SHY', 'SYY.SG', 'XER.BE', 'IRET', 'TM', 'CMI', 'YACKX', 'ADT', 'AAN', 'RRC', 'HOT', 'SWN', 'NCR', 'ADT.F', 'ETE', 'IONS', 'NUE', 'SPY160219P00180000', 'TBF', 'ITC', 'QLIK', 'CIT', 'LNT', 'LQDT', 'CVC', 'DISCK', 'GAS', 'SBUX.SW', 'NBL', 'KLXI', 'NWN', 'KRFT', 'FANG', 'GPRO', 'CY', 'CHL', 'ALTR', 'MSACX', 'VADDX', 'NGIPX', 'WSTMX', 'VMIIX', 'VSMIX', 'ACSDX', 'MGEMX', 'BUNT-RP', 'CVG', 'ATML', 'SMEZ', 'CMCSK', 'AR', 'NGLS', 'XLS-WI', 'XRT', 'KORS', 'PCAR', 'TU', 'SLY', 'IBKC', 'DTE', 'PRPFX', 'LINE', 'ESV', 'XLU', 'XLV', 'PCY', 'CMRE', 'MIK', 'ACT', 'JCOM', 'WAGE', 'VSI', 'TYPE', 'TXRH', 'TUMI', 'TTC', 'TNGO', 'THS', 'THRM', 'TECH', 'TCBI', 'SXT', 'SWI', 'SSB', 'SQI', 'SPSC', 'SMTC', 'SIGI', 'SHOO', 'SGY', 'RRTS', 'ROLL', 'RBA', 'RAVN', 'PRLB', 'PRIM', 'PRAA', 'PRA', 'POWI', 'PLT', 'PLKI', 'PEB', 'PBH', 'OMCL', 'NSR', 'NICE', 'MNRO', 'MG', 'MFRM', 'MDCA', 'LSTR', 'LOCK', 'LL', 'KWR', 'JJSF', 'IPCM', 'ICUI', 'ICON', 'HUBG', 'IART', 'HLX', 'HF', 'HEI', 'HCSG', 'GMED', 'FNGN', 'FMBI', 'FET', 'EVR', 'EPAY', 'EGBN', 'DRQ', 'DIOD', 'DFRG', 'CYBX', 'CVLT', 'CTRL', 'CTCT', 'CRZO', 'CMN', 'CLC', 'CHEF', 'CASY', 'BMR', 'BECN', 'BCPC', 'ATRO', 'AMSG', 'ALE', 'AKRX', 'AFSI', 'ABCO', 'AAT', 'AAON', 'ACE', 'NOG', 'COH', 'TOLLX', 'WASCX', 'MDDVX', 'DVFAX', 'BEAV', 'RYN', 'CEA', 'KSU', 'BTF', 'MFCDX', 'TFX', 'ROP', 'PCP', 'APH', 'OLN', 'COF-PP', 'VIXY', 'CDK', 'AJG', 'NOV', 'ESS', 'HYT', 'ISIS', 'IJH', 'IXP', 'SDY', 'DWX', 'ILF', 'EPP', 'MDP', 'LNKD', 'RYAM', 'LGP', 'BTE', 'BWA', 'ECL', 'EPR', 'ENLC', 'HCC', 'HUB-B', 'HTGC', 'LECO', 'OGS', 'PGH', 'PBCT', 'PL', 'STE', 'WASH', 'MLPRX', 'LNC', 'NTI', 'LMGEX', 'TCAP', 'SBGI', 'ROC', 'PNM', 'PRE', 'HFC', 'FNF', 'CMO', 'AIT', 'DBP', 'YHOO', 'VVC', 'VR', 'VRX', 'UMPQ', 'TAL', 'PWE', 'PACW', 'MGRC', 'MTSC', 'LDR', 'HMC', 'HTS', 'HNI', 'FLY', 'FMER', 'FFBC', 'CYS', 'CNSL', 'CPSI', 'CTBI', 'CLNY', 'CHCO', 'CBT', 'ALV', 'ADC', 'VDC', 'XRAY', 'KMP', 'CG', 'BHI', 'SCHW', 'LBTYK', 'LBTYA', 'ZMH', 'WIN', 'JPJQL', 'VAR', 'SJR', 'EC', 'RIG', 'BFK', 'SYMC', 'ILPT', 'KPLTW', 'AMD', 'SLVM', 'DUKH', 'OLP', 'SCU', 'VIASP', 'COIN', '--', 'ACAD', 'AGNC', 'ALLK', 'PLAN', 'ASB', 'BCEL', 'AXSM', 'BRMK', 'CPE', 'SAVA', 'CDEV', 'CIVI', 'CTRA', 'UUUU', 'EXPE', 'FNB', 'FHN', 'GNKOQ', 'GNK', 'GEVO', 'IIPR', 'KRG', 'KOS', 'MAC', 'NBR', 'NEX', 'NAT', 'NWBI', 'OCFC', 'OCGN', 'DOC', 'RC', 'RWT', 'SBRA', 'STNG', 'TELL', 'RTL', 'UEC', 'VTRSV', 'BHC', 'BYD', 'CTLT', 'CBRE', 'CNC', 'ENV', 'AQUA', 'LKQ', 'MAS', 'NXST', 'RP', 'COO', 'UNVR', 'USFD', 'MTN', 'WH', 'BSX', 'SPCE', 'COLD', 'LEE', 'JIH', 'RGLD', 'FMS', 'ACGL', 'PAG', 'NFG', 'LUMN', 'BKR', 'SWK', 'SFE', 'AMED', 'ANSS', 'CSGP', 'DORM', 'LOPE', 'GWRE', 'LII', 'NEOG', 'PCTY', 'ROL', 'TDOC', 'VRSK', 'SYPR', 'DOX', 'BURL', 'CIEN', 'HAE', 'STOR', 'WSO', 'ZBRA', 'GPN', 'ULTA', 'GDRX', 'HES', 'NI', 'SON', 'VRSN', 'CBOE', 'BRKS', 'CSTL', 'CCMP', 'DASTY', 'FXM', 'IFNNY', 'MEDP', 'PHR', 'SITE', 'VCYT', 'PLXS', 'NVT', 'FCFS', 'WWD', 'EXPD', 'AVY', 'EPAM', 'MCRN', 'MUR', 'CW', 'CLNE', 'BOOT', 'BEN', 'HQY', 'NCLTY', 'OLLI', 'PATK', 'CSPCY', 'PNGAY', 'SYNH', 'ACI', 'CCL', 'CCXX', 'GGT', 'NMIH', 'NLOK', 'RSG', 'TOL', 'PEAK', 'DOMO', 'INTL', 'FLL', 'ESTC', 'APPL', 'SNV', 'FVRR', 'FNV', 'LDNXF', 'NGL', 'PBFX', 'SGENX', 'SCHP', 'BKI', 'HHC', 'URGO', 'APHA', 'ESGC', 'TLRY', 'IPWR', 'IFF', 'PDBC', 'IAU', 'IBDP', 'HYBB', 'IBDU', 'IBTK', 'SPDW', 'SLYG', 'SLYV', 'AAPl', 'CHWY', 'CNA', 'RARE', 'WMC', 'BIAWX', 'APCD', 'OWLSX', 'ALIZY', 'ATRC', 'EXAS', 'LCRX', 'MTDR', 'SF', 'LINK-USD', 'ENBL', 'GLP', 'USAC', 'LTD', 'SAIC', 'JOE', 'ENS', 'NVEE', 'OSW', 'SGIOY', 'ELV', 'FRC', 'FISV', 'DBRG', 'SCHD', 'INFO', 'SBAC', 'HUM', 'ASMB', 'RETA', 'SRNE', 'Z', 'WSM', 'WCC', 'WAIR', 'VNT', 'VRT', 'GT', 'AZEK', 'SVC', 'RLGY', 'LESL', 'GO', 'FLT', 'DRE', 'DLTR', 'CHNG', 'CHX', 'CDW', 'CACI', 'AHCO', 'TEAM', 'BRK.A', 'DIN', 'KTOS', 'ACHC', 'ADDDYY', 'ALC', 'ALFVY', 'ADS', 'ABEV', 'ATH', 'ATLKY', 'BBVA', 'CNI', 'CHGCY', 'XEC', 'CLGX', 'CCK', 'DBSDY', 'DXC', 'EMN', 'EHC', 'EQIX', 'FMX', 'FUPBY', 'HDB', 'HRC', 'IBN', 'IDXXX', 'ITUB', 'JBL', 'KKR', 'KMTUY', 'KUBTY', 'AIQUY', 'LZAGY', 'LUKOY', 'MSI', 'MSCI', 'NYT', 'NEM', 'NVZMY', 'NVR', 'OKTA', 'OMF', 'PH', 'PNC', 'RDS.B', 'SC', 'SBGSY', 'SEE', 'SGSOY', 'SONVY', 'SYIEY', 'SSMXY', 'TRU', 'UNICY', 'WYND', 'YNDX', 'ZG', 'FNRVGX', 'AFRM', 'GFS', 'MP', 'UPST', 'BBH', 'ORCC', 'SKIN', 'WYNN', 'EMBC', 'ADTN', 'DTEGY', 'SANM', 'BXS', 'RBCAA', 'JBI', 'STM', 'AVB', 'AGR', 'BLKB', 'CREE', 'FSLR', 'IPG', 'JLL', 'LHCG', 'LPLA', 'ORA', 'RGA', 'TTEK', 'AMJ', 'MDY', 'NWM', 'HII', 'NSP', 'REYN', 'PHG', 'NTRS', 'FTDR', 'ALLY', 'AMP', 'ARMK', 'AVTR', 'CHDN', 'DOV', 'ENR', 'EFX', 'WTRG', 'FND', 'FMC', 'GLIBA', 'LBDAV', 'PFGC', 'PLNT', 'SERV', 'SIRI', 'SSNC', 'CNP', 'FLS', 'L', 'SNE', 'WTFC', 'OLED', 'REGL', 'FPE', 'PFFV', 'VRP', 'BBVLX', 'BBVSX', 'VTV', 'GXO', 'ADYEY', 'RGEN', 'BOWX', 'TGNA', 'YTRA', 'ETRN', 'AAWW', 'ALXN', 'CYRX', 'HMN', 'PPBI', 'POL', 'PFPT', 'RPD', 'NOW', 'SKY', 'WMGI', 'CSQ', 'FDL', 'GSLC', 'USMC', 'DIA', 'VIG', 'RUN', 'VSLR', 'CTRCF', 'QGEN', 'MBB', 'IGLB', 'IEMG', 'EMXC', 'IBTD', 'MDYG', 'MDYV', 'LCGFX', 'SGIIX', 'FUND', 'STLA', 'DEACU', 'BGFV', 'PSNL', 'SDC', 'EQUIX', 'LDOS', 'NRG', 'TDDXX', 'CRYX', 'GH', 'AXHE', 'AXTE', 'TRNO', 'CXW', 'STAY', 'CGC', 'CIM', 'FEI', 'UAL', 'KRR', 'BAFWX', 'HP', 'IMAX', 'AEG', 'DUK$A', 'FLO', 'MFC', 'OXBR', 'SCHZ', 'BRP', 'JEF', 'ESGD', 'NUGL', 'OWSMX', 'RF$A', 'AROC', 'GLOP', 'GMLP', 'MMLP', 'NBLX', 'SPH', 'SMLP', 'IAC', 'TMUSR', 'BIPC', 'DKNG', 'CODYY', 'DPSGY', 'SVNLY', 'TKOMY', 'ENPH', 'SGEN', 'UFPI', 'EOG', 'WRK.V', 'ANET', 'HWM', 'DAIUF', 'FANUF', 'LVMHF', 'SPLK', 'WFC$V', 'ABNB', 'SAM', 'EBS', 'HUBS', 'MELI', 'MDB', 'SLAB', 'TPR', 'TWLO', 'WSC', 'Y', 'PAVE', 'VCSH', 'IX', 'VXX', 'AMZA', 'USDP', 'ALFY', 'AMRC', 'CWH', 'CCC', 'COMM', 'CWK', 'LITE', 'TNL', 'VICI', 'WHR', 'LARCX', 'AI', 'CDNA', 'CMLFU', 'DASH', 'EVBG', 'QDEL', 'MTBC', 'ICLR', 'PRGS', 'PTC', 'VUZI', 'FEDX', 'VRAI', 'BLUE', 'BR', 'FLIR', 'RAD', 'WORK', 'TRUP', 'MKL', 'FPEI', 'RBLX', 'H', 'ALK', 'LUV', 'CMP', 'HSHCY', 'HTLD', 'HLIO', 'MAIN', 'FTTGLX', 'SRLP', 'ATO', 'ED', 'ADDYY', 'BPHSPX', 'CANO', 'NLY', 'ABMD', 'CENT', 'CENTA', 'CRY', 'DNTUY', 'SSL', 'HOFV', 'IWB', 'PSDTX', 'SPDR', 'ANY', 'RIVN', 'FAS', 'AZTA', 'CCXI', 'XNGSY', 'ITCI', 'MTX', 'XP', 'CSL', 'AVT', 'BG', 'MEOH', 'SNOXX', 'AIR', 'ALGT', 'BXP', 'GOOS', 'CPRI', 'CF', 'COTY', 'EXLS', 'FLEX', 'GBCI', 'GLOB', 'HRB', 'HOG', 'HPE', 'HST', 'ICFI', 'IDA', 'JBT', 'KIM', 'LEN', 'LAD', 'MGM', 'NHI', 'NATI', 'NCLH', 'PFG', 'PEG', 'PVH', 'PWR', 'SLG', 'TTWO', 'AMTD', 'DSGX', 'UHS', 'UNM', 'VC', 'VNO', 'WBS', 'WELL', 'LEVI', 'UBS', 'OIH', 'DGRO', 'CWB', 'FLGB', 'SPHB', 'IEUR', 'EFG', 'XLE', 'AB', 'SEA', 'FIX', 'IQVA', 'NUSC', 'CVI', 'CATM', 'ESI', 'LTHM', 'THR', 'WK', 'BDN', 'BRBR', 'FORD', 'NVCR', 'CISIX', 'QS', 'LZ', 'INMD', 'GPP', 'KNOP', 'ORI', 'SIRE', 'WBD', 'HEFA', 'SHYG', 'IEFA', 'BBCA', 'JEPI', 'SRLN', 'BND', 'BXMT', 'ALb', 'DTM', 'PYPLV', 'MGNA', 'NTR', 'MSBHY', 'CRNC', 'CNS', 'DAVA', 'PRAH', 'SUPN', 'SHYF', 'VRTU', 'FCGAX', 'FNGZX', 'FLCO', 'FLCB', 'FLQL', 'FSSAX', 'FVADX', 'GCIIX', 'GOVT', 'OMBIX', 'LSFYX', 'PIMIX', 'SPTM', 'TBCIX', 'TDADX', 'NEO', 'RDS.A', 'TWST', 'RXT', 'CNK', 'DCI', 'MHK', 'BPMP', 'EMKR', 'ACST', 'CTRM', 'CELO', 'ADSK', 'HZD', 'RHHBF', 'BEEM', 'PXD', 'NULC', 'CSVIX', 'BNS', 'VMBS', 'BNDX', 'ESGU', 'CRAIX', 'DGCAX', 'TSBIX', 'JSOSX', 'PRMSX', 'MEIAX', 'OAKIX', 'DEVLX', 'EGFIX', 'FLJP', 'KBWB', 'IEF', 'TLT', 'EFV', 'IYW', 'MSEQX', 'GSS', 'ORMP', 'BROS', 'UHG', 'PEJ', 'LRNZ', 'WCLD', 'GPS', 'LCID', 'HLEIX', 'HUYA', 'BVALX', 'ASXC', 'PHX', 'BTC-USD', 'INDB', 'VAIAF', 'FAFTX', 'FIXD', 'TLH', 'CMLTU', 'ETWO.W', 'GFN', 'PCRX', 'TDC', 'DINO', 'WDFC', 'ERJ', 'IBTB', 'IBTJ', 'IBTI', 'IBTH', 'IBTG', 'SPYS', 'SPYV', 'SPTI', 'LQD', 'XLF', 'TPCO', 'KMPR', 'RUSHA', 'SKVKY', 'SM', 'ACHO', 'BALL', 'BBWI', 'BRO', 'BLDR', 'CLVT', 'DSEY', 'GFL', 'QRVO', 'FOUR', 'XYL', 'ANAYX', 'VTABX', 'PI', 'CWEN.A', 'BALY', 'DESY', 'POOL', 'VVNT', 'VGPBF', 'ABCB', 'CDAY', 'ETFC', 'EDU', 'RCI', 'SBCF', 'SLGN', 'BMRN', 'CVNA', 'CATY', 'LYFT', 'EBSB', 'ROG', 'HZN', 'MFH', 'JAZZ', 'BH', 'BF.B', 'ESGR', 'FRFHF', 'POST', 'MAA', 'RQI', 'AMN', 'AAM$A', 'BTI', 'COF-CD', 'SWPPX', 'PK', 'PPC', 'TIF', 'IAA', 'SEDG', 'PLTR', 'DANOY', 'EIX', 'IGV', 'NULG', 'SPYG', 'CSIQ', 'CINF', 'HTA', 'LAMR', 'NNN', 'SLV', 'XHB', 'XLB', 'XLK', 'PBF', 'BLDr', 'VSCO', 'CS', 'WBK', 'CLNC', 'IS', 'AIO', 'FSKR', 'EBJ', 'POR', 'AEIS', 'AlGM', 'ALGM', 'CHGG', 'DOGE-USD', 'MS$P', 'SCHF', 'FS', 'TIP', 'ETH-USD', 'KRYLL-USD', 'KYRLL-USD', 'LGB-USD', 'REQUEST-USD', 'SOL-USD', 'AROW', 'FMCMF', 'GCP', 'GRA', 'CRL', 'MRNA', 'PYCR', 'QTS', 'SPXC', 'ANPDF', 'GTN', 'HRTX', 'MCS', 'QCHR', 'SHAK', 'ARLP', 'PFF', 'SPR', 'NIO', 'FTA', 'CHPT', 'FIKMX', 'GBDC', 'VONE', 'WSTL', 'HTZ', 'BXS$A', 'PAIDX', 'WLTL', 'SNN', '35G.SG', 'TRN', 'WLTW', 'BRX', 'AMCX', 'LGND', 'EVH', 'RTC', 'BOOK', 'Book', 'CTRX', 'DIAL', 'FMAT', 'SCHH', 'SRPT', 'QYLD', 'BTEC', 'BBBY', 'FTSM', 'QSY', 'FMAO', 'PDX', 'TWNK', 'VRNT', 'MRCK', 'USO', 'BAC$K', 'DNB', 'BAESY', 'SMFKY', 'SPWR', 'ONVO', 'FCEL', 'IGT', 'MAXN', 'CPRT', 'LAND', 'AOS', 'NUVA', 'DUKE', 'GOGL', 'IMKTA', 'NEWT', 'SJT', 'TSS', 'USD-LGB', 'HPP', 'ARQT', 'AVNT', 'DFKCY', 'ITT', 'PPRUY', 'NTDOY', 'VBTX', 'FLYW', 'TWKS', 'KBH', 'ZROZ', 'DXJ', 'AVYA', 'SFST', 'TRBCX', 'VWIGX', 'NFFFX', 'PRGTX', 'RPBAX', 'OAKGX', 'DODWX', 'AIMC', 'ORLT', 'VFF', 'AHT', 'WXA.F', 'HEP', 'UTG', 'XMO', 'AD', 'LAM', 'TF', 'VTRA', 'LBDRA', 'BCRX', 'BBGLX', 'AZSEY', 'EWU', 'VNQ', 'VMN', 'ARKG', 'ICSH', 'NBIX', 'GPC', 'TME', 'RAND', 'RCKY', 'UTGN', 'NVVE', 'HUBB', 'R', 'TRGIX', 'BSIXX', 'AVLR', 'SVCBY', 'ENLAY', 'VALE', 'AAIGF', 'KAI', 'BE', 'ACM', 'HRI', 'MPLN', 'GCGMF', 'SEK', 'KYOCF', 'MITK', '7XY', 'TNC', 'MGY', 'VOX', 'RNGR', 'PRWCX', 'AMADY', 'EPOKY', 'KIDS', 'GSAH', 'PLYA', 'XLP', 'HOn', 'ORAN', 'SONY', 'OMC', 'SNNUF', 'FBSI', 'AAIC$B', 'CPXWF', 'FHLC', 'HCRB', 'OWMBX', 'AMTX', 'HS', 'PAHC', 'NSIT', 'FCN', 'AWI', 'GHC', 'WB2.SG', 'YETI', 'BRK', 'FVD', 'BLDP', 'PARMX', 'AKRO', 'ATHA', 'BLFS', 'ENOB', 'FLNG', 'HSAC', 'KOD', 'RLMD', 'SbrA', 'TLRN', 'PCVX', 'ARTIX', 'FGTXX', 'BBIEX', 'GVA', 'ABM', 'ADUS', 'AMBA', 'AMH', 'AOBC', 'ARI', 'APLE', 'ARR', 'APNHY', 'AGO', 'AXGN', 'BKU', 'BAYRY', 'BAMXY', 'BIG', 'CVGW', 'CMD', 'CCS', 'PLCE', 'CHH', 'CMPR', 'CRUS', 'CDE', 'CCOI', 'CXP', 'CTB', 'DBD', 'BOOM', 'DLB', 'EGP', 'ESNT', 'EXEL', 'FII', 'FAF', 'FFIN', 'FIBK', 'FBC', 'FOXF', 'GCI', 'GCO', 'G', 'GBT', 'GBX', 'GRFS', 'GBOOY', 'HE', 'HL', 'HIW', 'XENT', 'IRTC', 'JGCCY', 'KMT', 'LLL', 'LANC', 'LAUR', 'MANH', 'DOOR', 'MED', 'MD', 'MTH', 'MGPI', 'MSTR', 'MC', 'MONOY', 'DNOW', 'NTNX', 'OXM', 'PGRE', 'PKCOY', 'PEGI', 'PDCE', 'PNR', 'PNW', 'PS', 'PCH', 'PUMP', 'PB', 'PSB', 'PBYI', 'RDUS', 'RDFN', 'RCII', 'REXR', 'SCHN', 'SITC', 'SAVE', 'SRC', 'TMHC', 'TMSNY', 'TPX', 'TS', 'TRMB', 'TRMK', 'USPH', 'UTHR', 'UVV', 'VRNS', 'VCRA', 'WDR', 'WAFD', 'WTS', 'WB', 'WING', 'YEXT', 'ZEN', 'ZION', 'UDR', 'FFRHX', 'FFHRX', 'FSTFX', 'IVE', 'VGT', 'MALRX', 'BTZ', 'DSU', 'MADCX', 'MAYHX', 'MANLX', 'BGSIX', 'EVV', 'DIV', 'GSMTX', 'HGIIX', 'USMV', 'VLUE', 'IHI', 'PMUPX', 'RNSIX', 'VTI', 'PUTW', 'XSOE', 'BAND', 'INO', 'SNX', 'TGTX', 'MNTA', 'WABC', 'TAK', 'CMCAS', 'BBNTX', 'SCZ', 'GISYX', 'ERH', 'OZKAP', 'TXT', 'AMC', 'SFY', 'BJ', 'MFYV', 'BGG', 'AOSL', 'BL', 'EVGB', 'FIVN', 'VIVO', 'OSUR', 'TDDC', 'RTNB', 'BIP', 'BEP', 'TYL', 'VFC.VI', 'BAT-USD', 'CELO-USD', 'ETC-USD', 'XLM-USD', 'CO', 'NWWOX', 'KPLT', 'OWSOX', 'PASO', 'HIPO', 'EGHT', 'ANIK', 'APEN', 'BLFSD', 'CSLT', 'PCPL', 'PCPL.U', 'CELC', 'CNF', 'DMTK', 'FLXN', 'APPAD', 'INST', 'SMJ', 'NVIGF', 'ONTO', 'PROF', 'REG', 'TRHC', 'TLND', 'TFFP', 'VIOT', 'ZUO', 'FBKWX', 'IVW', 'AABV', 'JEPQ', 'SSGA', 'INVH', 'SKX', 'AQB', 'T$A', 'CADE$A', 'COF$I', 'JPM$J', 'KEY$J', 'RF$E', 'TFC$R', 'WFC$Y', 'ASBC', 'CRGY', 'ESTE', 'NOTV', 'ISEE', 'USBI', 'VTNR', 'GTLS', 'FTLS', 'BSK', 'UI', 'FFG', 'PARA', 'ETV', 'FSEN', 'INRE', 'FSD', 'MARA', 'CHV', 'BDC', 'PGNY', 'TBBC', 'BUI', 'EXI', 'KYN', 'IBTF', 'HAYN', 'UNF', 'UPLD', 'CRTL', 'SUP', 'BOA', 'Broadcom Inc.', 'MJNA', 'ACB', 'CRON', 'QMCO', 'IWV', 'WDS', 'INSM', 'SHLS', 'ARCB', 'CCLD', 'EOS-USD', 'DAWC', 'ADA-USD', 'KMLW', 'MTSI', 'SPKE', 'DMRC', 'ZOOM', 'MZOR', 'TYG', 'VAW', 'BOH', 'AAl', 'BP PLC', 'LPRO', 'STXAX', 'VUL.V', 'GOOC.VI', 'NULV', 'CFJIX', 'BRHYX', 'BBTBX', 'VEU', 'IWR', 'GSOSX', 'BBCBX', 'SMHLX', 'JQC', 'CFJAX', 'BSIIX', 'JSOAX', 'TSBRX', 'BHPLF', 'NLG', 'HYDB', 'RY.TO', 'CSCCX', 'CHUY', 'TCOM', 'WCG', 'KRNT', 'PRSP', 'TRREX', 'DFREX', 'ALNY', 'FISI', 'PONPX', 'HIL', 'GRNC', 'DWAC', 'BCE', 'PGX', 'MDNDF', 'AMKBY', 'ELUXY', 'AAVMY', 'AHEXY', 'AGESY', 'ALPMY', 'ATASY', 'ANZBY', 'AVVIY', 'BCS', 'BHKLY', 'BNTGY', 'BTLCY', 'BURBY', 'CAJ', 'CRRFY', 'CCLAY', 'CRZBY', 'CMWAY', 'COVTY', 'DWAHY', 'DNKEY', 'DNZOY', 'DB', 'DTCWY', 'DSDVY', 'ENGGY', 'GEAGY', 'HLUYY', 'HVRRY', 'HDELY', 'HNNMY', 'HXGBY', 'IBDRY', 'IMBBY', 'ING', 'IHG', 'JSAIY', 'JHX', 'JAPSY', 'JAPAY', 'JBAXY', 'KGFHY', 'KNRRY', 'VOPKY', 'LYG', 'LNSTY', 'MZDAY', 'MDIBY', 'MFGP', 'MITEY', 'MFG', 'NTOIY', 'NINOY', 'NSANY', 'NNGRY', 'NRDBY', 'DNNGY', 'PDYPY', 'PCRFY', 'PANDY', 'PSO', 'PROSY', 'PUBGY', 'RDEIY', 'RNLSY', 'REPYY', 'RBS', 'KKPNY', 'RWEOY', 'SVNDY', 'SMNNY', 'SMMNY', 'SXYAY', 'SCGLY', 'SZEVY', 'SWGAY', 'SWDBY', 'SWMAY', 'SWRAY', 'TIIAY', 'TEF', 'TLSNY', 'TEZNY', 'TSCDY', 'WFAFY', 'WCAGY', 'MRWSY', 'TDXX', 'IXJ', 'IYZ', 'HTZWW', 'SNP', 'ENGIY', 'INFR', 'ISD', 'VV', 'LEN.B', 'PSMMY', 'ARNC', 'AVNS', 'MBD', 'ECOL', 'BBGSX', 'LEG', 'SSLTY', 'ZIMV', 'DURA', 'BEKE', 'VWDRY', 'DDD', 'PSTH', 'SKYY', 'DBX', 'AGG', 'EWBC', 'MSB', 'NOVT', 'UNG', 'IBTE', 'BRCM', 'AE', 'LPT', 'BAGIX', 'FHYS', 'FDEV', 'FSMDX', 'EFA', 'CORP', 'SHCP', 'VUG', 'VYM', 'JPM$G', 'FBALX', 'FDRXX', 'MRIN', 'AVXL', 'BORR', 'MNRL', 'CHRD', 'CMTG', 'COGT', 'XPRO', 'INSW.V', 'KALV', 'KRYS', 'KURA', 'NESR', 'NTST', 'PR', 'SWTX', 'HNST', 'LGF.B', 'EHSTX', 'NVLIX', 'ITOT', 'IBKR', 'MORN', 'DUSA', 'UGRO', 'AATC', 'FSKAX', 'FEPAX', 'SPN', 'TFDXX', 'CIG', 'EQNR', 'JGCCF', 'MJDLF', 'MLYNF', 'NCMGF', 'OGFGF', 'PDS', 'VIV', 'TSCDF', 'TKC', 'WOLWF', 'AUY', 'ETON', 'ACCYY', 'ACSAY', 'AER', 'SAN', 'BGNE', 'CUK', 'CRARY', 'DLAKY', 'EJPRY', 'E', 'EVVTY', 'FINMY', 'GLPEY', 'HLPPY', 'HSNGY', 'HLDCY', 'HTHIY', 'ICL', 'IPXHY', 'ISNPY', 'ISUZY', 'KPELY', 'MLCO', 'MUFG', 'MITSY', 'NABZY', 'NTXFY', 'NWG', 'NTTYY', 'OMVKY', 'POAHY', 'PUK', 'RYCEY', 'SKFRY', 'SDXAY', 'FUJHY', 'SOMMY', 'SSUMY', 'SMFG', 'SUHJY', 'SSREY', 'TLSYY', 'TRYIY', 'VONOY', 'WJRYY', 'WIX', 'WOPEY', 'WPP', 'MYE', 'GWPH', 'STWD', 'FBGRX', 'FTQGX', 'FLVEX', 'FBMPX', 'FSCPX', 'FIDSX', 'FSPHX', 'FCYIX', 'FSPTX', 'FDIS', 'FTEC', 'FBND', 'AMLX', 'PLL', 'DENN', 'VBR', 'MINI', 'NWE', 'RXN', 'FSP', 'ASGN', 'HCN', 'NEE$Q', 'BREW', 'AGI', 'ABALX', 'NGF', 'CWGIX', 'AIVSX', 'ANWPX', 'NEWFX', 'VMCXX', 'AESE', 'HNDL', 'NLSN', 'AFTPY', 'LOGI', 'DCMYY', 'MNP', 'BXMDX', 'JEMWX', 'TGOPY', 'VOLVY', 'AMCR', 'EVRG', 'MGDDY', 'PWCDF', 'DNBBY', 'TRI', 'UGI', 'XYIGY', 'OWCIX', 'JFAMX', '^GSPC']

# symbols=list(set(symbols))
# dfs=[]
# while len(symbols)>0:
#     tickers = Ticker(symbols[:8], asynchronous=False)
#     data = tickers.get_modules("summaryProfile quoteType")
#     df = pd.DataFrame.from_dict(data).T
#     dataframes = [pd.json_normalize([x for x in df[module] if isinstance(x, dict)]) for module in 'summaryProfile', 'quoteType']]
#     df = pd.concat(dataframes, axis=1)
#     df=df[['symbol', 'shortName', 'sector', 'industry', 'exchange']]
#     dfs.append(df)
#     symbols=symbols[8:]
# df = pd.concat(dfs)
# df=df.reset_index()
# dupes = (df['symbol'].drop_duplicates())
# print(len(dupes)/len(df))
# # df=df.loc[dupes.index,:]
# df=df.set_index('symbol')
# # df.loc['AAPL',['sector', 'industry']]=['Technology', 'Consumer Electronics']
# df[['shortName', 'sector', 'industry']].head(10)

# %%
len('No fundamentals data found')
# Out:
# 26

# %%
Ticker('DUK$A').get_modules('summaryProfile').get('DUK$A')

# %%
df = pd.DataFrame(columns=['symbol', 'sector','industry'])
unavalible=[]
# symbols = ['AMZN','MSFT','TSLA']
for symbol in symbols:
    ticker = Ticker(symbol)

    if ticker.get_modules("summaryProfile").get(symbol)==None or str(ticker.get_modules("summaryProfile").get(symbol))[0:15]=='Quote not found' or str(ticker.get_modules("summaryProfile").get(symbol))[0:26] == 'No fundamentals data found':
        print("not found for "+str(symbol))
        unavalible.append(symbol)
    else:
        #print(ticker.get_modules("summaryProfile").get(symbol))
        data = {'symbol':symbol,'sector':ticker.get_modules("summaryProfile").get(symbol).get('sector'),'industry':ticker.get_modules("summaryProfile").get(symbol).get('industry')}
        df.loc[len(df),:]=data
    # print(data)
df
# Out:
# not found for RNWK
# not found for LDP
# not found for ECOM
# not found for BKEPP
# not found for BRK.B
# not found for TCF
# not found for TACO
# not found for BMO
# not found for GEMIX
# not found for FB
# not found for BKEP
# not found for CTAA
# not found for LMRK
# not found for COR
# not found for RDSA
# not found for CNR
# not found for FDSWX
# not found for ETHE
# not found for GBTC
# not found for FL4.SG
# not found for NUAN
# not found for TRIT
# not found for DGNR
# not found for LMACU
# not found for XCAPX
# not found for FEYE
# not found for DNKN
# not found for NTRP
# not found for MANT
# not found for CONE
# not found for ARNA
# not found for RDS-B
# not found for BLL
# not found for RTN
# not found for VIAC
# not found for WPX
# not found for EQM
# not found for ANTM
# not found for UN
# not found for PSXP
# not found for TCP
# not found for SHLX
# not found for SOJA
# not found for BIF
# not found for GRUB
# not found for UTX
# not found for AGN
# not found for CTXS
# ...

# %%
df=df.set_index('symbol')

# %%
print(df.loc['INTC',['industry', 'sector']])
# Out:
# industry    Semiconductors
# sector          Technology
# Name: INTC, dtype: object

# %%
for i in list(set(df['sector']))[1:]:
    print(i)
    print(str(list(set(df['industry'][df['sector']==i]))))
# Out:
# Industrials
# ['Specialty Business Services', 'Metal Fabrication', 'Waste Management', 'Industrial Distribution', 'Railroads', 'Rental & Leasing Services', 'Engineering & Construction', 'Airlines', 'Building Products & Equipment', 'Aerospace & Defense', 'Farm & Heavy Construction Machinery', 'Tools & Accessories', 'Consulting Services', 'Trucking', 'Marine Shipping', 'Airports & Air Services', 'Security & Protection Services', 'Infrastructure Operations', 'Integrated Freight & Logistics', 'Business Equipment & Supplies', 'Specialty Industrial Machinery', 'Staffing & Employment Services', 'Conglomerates', 'Electrical Equipment & Parts', 'Pollution & Treatment Controls']
# Healthcare
# ['Medical Devices', 'Health Information Services', 'Medical Instruments & Supplies', 'Drug Manufacturers—General', 'Biotechnology', 'Healthcare Plans', 'Drug Manufacturers—Specialty & Generic', 'Diagnostics & Research', 'Medical Distribution', 'Pharmaceutical Retailers', 'Medical Care Facilities']
# ...

# %%
str(list(set(df['industry'][df['sector']=='Healthcare'])))
# Out:
# "['Medical Devices', 'Health Information Services', 'Medical Instruments & Supplies', 'Drug Manufacturers—General', 'Biotechnology', 'Healthcare Plans', 'Drug Manufacturers—Specialty & Generic', 'Diagnostics & Research', 'Medical Distribution', 'Pharmaceutical Retailers', 'Medical Care Facilities']"

# %%
committee_to_industry_dict= {
    'labor':[],
    'rules':[],
    'health':['Medical Distribution', 'Medical Instruments & Supplies', 'Biotechnology', 'Health Information Services', 'Drug Manufacturers—Specialty & Generic', 'Pharmaceutical Retailers', 'Medical Care Facilities', 'Drug Manufacturers—General', 'Healthcare Plans', 'Diagnostics & Research', 'Medical Devices'],
    'energy':['Solar','Oil & Gas Refining & Marketing', 'Oil & Gas E&P', 'Oil & Gas Midstream', 'Uranium', 'Thermal Coal', 'Oil & Gas Integrated', 'Oil & Gas Drilling', 'Oil & Gas Equipment & Services', 'Utilities—Regulated Electric', 'Utilities—Renewable', 'Utilities—Diversified', 'Utilities—Regulated Gas', 'Utilities—Independent Power Producers'],
    'budget':[],
    'banking': ['Banks—Diversified', 'Banks—Regional'],
    'science':['Biotechnology', 'Diagnostics & Research', 'Electronics & Computer Distribution', 'Consumer Electronics', 'Semiconductors', 'Solar', 'Communication Equipment', 'Software—Application', 'Computer Hardware', 'Electronic Components', 'Semiconductor Equipment & Materials', 'Software—Infrastructure', 'Scientific & Technical Instruments', 'Information Technology Services'],
    'finance':['Insurance—Life', 'Insurance—Reinsurance', 'Capital Markets', 'Mortgage Finance', 'Insurance—Property & Casualty', 'Shell Companies', 'Credit Services', 'Insurance—Diversified', 'Asset Management', 'Financial Data & Stock Exchanges', 'Insurance Brokers', 'Banks—Diversified', 'Insurance—Specialty', 'Banks—Regional'],
    'housing':['REIT—Specialty', 'REIT—Industrial', 'REIT—Healthcare Facilities', 'REIT—Office', 'REIT—Residential', 'REIT—Mortgage', 'Real Estate—Development', 'REIT—Diversified', 'REIT—Hotel & Motel', 'Real Estate Services', 'REIT—Retail', 'Real Estate—Diversified'],
    'commerce':['Advertising Agencies', 'Discount Stores', 'Travel Services', 'Restaurants', 'Specialty Retail', 'Auto & Truck Dealerships', 'Resorts & Casinos', 'Auto Manufacturers', 'Packaging & Containers', 'Footwear & Accessories', 'Apparel Retail', 'Leisure', 'Internet Retail', 'Personal Services', 'Residential Construction', 'Lodging', 'Textile Manufacturing', 'Gambling', 'Home Improvement Retail', 'Department Stores', 'Luxury Goods', 'Apparel Manufacturing', 'Furnishings, Fixtures & Appliances', 'Auto Parts', 'Recreational Vehicles'],
    'pensions':[],
    'forestry':['Lumber & Wood Production','Paper & Paper Products'], 
    'nutrition':['Restaurants', 'Confectioners', 'Beverages—Brewers', 'Farm Products', 'Beverages—Wineries & Distilleries', 'Packaged Foods', 'Tobacco', 'Discount Stores', 'Food Distribution', 'Grocery Stores', 'Beverages—Non-Alcoholic'], 
    'education':['Education & Training Services'], 
    'agriculture':['Farm Products', 'Agricultural Inputs','Farm & Heavy Construction Machinery','Food Distribution', 'Grocery Stores'], 
    'publicworks':[], 
    'environment':['Utilities—Renewable','Paper & Paper Products','Pollution & Treatment Controls','Waste Management','Solar'], 
    'urbanaffairs':[], 
    'armedservices':['Aerospace & Defense'], 
    'appropriations':[], 
    'transportation':['Auto Parts', 'Auto & Truck Dealerships', 'Auto Manufacturers', 'Airlines', 'Railroads', 'Trucking', 'Marine Shipping', 'Integrated Freight & Logistics', 'Airports & Air Services','Infrastructure Operations'], 
    'foreignrelations':[], 
    'homelandsecurity':['Aerospace & Defense'], 
    'naturalresources':['Silver', 'Building Materials', 'Other Precious Metals & Mining', 'Steel', 'Coking Coal', 'Other Industrial Metals & Mining', 'Copper', 'Chemicals', 'Lumber & Wood Production', 'Gold', 'Aluminum', 'Agricultural Inputs', 'Paper & Paper Products', 'Specialty Chemicals', 'Utilities—Regulated Water','Solar','Oil & Gas E&P', 'Oil & Gas Refining & Marketing', 'Oil & Gas Drilling', 'Uranium', 'Thermal Coal', 'Oil & Gas Equipment & Services', 'Oil & Gas Midstream', 'Oil & Gas Integrated'], 
    'governmentalaffairs':[],
    'jointcongressionalcommitteeoninaugural':[]
}
def get_committee_from_industry(industry):
    out=[]
    for k in committee_to_industry_dict.keys():
        v = committee_to_industry_dict.get(k)
        if(industry in v):
            out.append(k)
    return out

def get_committees_from_industry_list(industries):
    out = []
    for industry in industries:
        out.append(get_committee_from_industry(industry))
    return out

# %%
# df['committee']=np.empty((len(df), 0)).tolist()
df['committee']=get_committees_from_industry_list(df['industry'])
df['empty']=np.empty((len(df), 0)).tolist()
len(df[df['committee']!=df['empty']])/len(df)
# Out:
# 0.6859002169197397

# %%
df['industry'].value_counts()
# Out:
# Banks—Regional                    87
# Asset Management                  67
# Biotechnology                     63
# Software—Application              59
# Software—Infrastructure           47
#                                   ..
# Business Equipment & Supplies      1
# Silver                             1
# Aluminum                           1
# Other Precious Metals & Mining     1
# Textile Manufacturing              1
# Name: industry, Length: 145, dtype: int64

# %%
df.to_csv('stock_info.csv')

# %%
df = pd.read_csv('stock_info.csv').set_index('symbol')
df.head()
# Out:
#                         sector                       industry  \
# symbol
# GOLD           Basic Materials                           Gold
# NU          Financial Services              Banks—Diversified
# DIS     Communication Services                  Entertainment
# PG          Consumer Defensive  Household & Personal Products
# KMB         Consumer Defensive  Household & Personal Products
#
#                      committee empty
# symbol
# GOLD      ['naturalresources']    []
# NU      ['banking', 'finance']    []
# DIS                         []    []
# PG                          []    []
# KMB                         []    []
